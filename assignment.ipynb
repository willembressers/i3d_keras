# %% [markdown]
# # Assignment
# The goal of this notebook, is to apply an I3D model on the images in the assignment directory.
#
# First let's load the required python packages

# %%
import os
import sys
import cv2
import sklearn
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics._plot.confusion_matrix import ConfusionMatrixDisplay

# ensure we can load the src folder from this notebook
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
print(f"numpy: {np.__version__}")
print(f"opencv: {cv2.__version__}"),
print(f"tensorflow: {tf.__version__}")
# Out:
# numpy: 1.19.5
# opencv: 4.5.1
# tensorflow: 2.4.1

# %% [markdown]
# I've forked the [i3d_keras](https://github.com/OanaIgnat/i3d_keras) repo so, that i could use their implementation and add my own code on top of it.

# %%
# OPTIONAL: Load the \"autoreload\" extension so that code can change
# %load_ext autoreload

# OPTIONAL: always reload modules so that as you change code in src, it gets loaded
# %autoreload 2

from src.preprocess import *
from src.i3d_inception import Inception_Inflated3d

# %% [markdown]
# ## About the data
# Let's show some images from the test directory

# %%
test_dir = os.path.join('data', 'assignment', 'test')

# read the images from the test directory, set shuffle to false to maintain file ordering
dataset = tf.keras.preprocessing.image_dataset_from_directory(
  test_dir,
  shuffle=False
)

# get the class names
class_names = dataset.class_names

# now show 9 images from the first batch
plt.figure(figsize=(10, 10))
for images, labels in dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")
# Out:
# Found 23861 files belonging to 5 classes.

# %% [markdown]
# ## Define the parameters
# In the input layer of the I3D model the shape is defined with `INPUT_SHAPE`. This represents the amount of images. Video's can have different lengths (nr of frames) so let's first figure out the different video lengths.

# %%
# loop over all class_names and video's and count the number of files per video
meta_data = []
for class_name in os.listdir(test_dir):
    for video_name in os.listdir(os.path.join(test_dir, class_name)):
        meta_data.append({
            'class_name':class_name,
            'video_name':video_name,
            'nr_files':len(os.listdir(os.path.join(test_dir, class_name, video_name))),
        })
        
# collect them in a dataframe
meta_data_frame = pd.DataFrame(meta_data)

# now show the file distribution
plt.title('Video length')
plt.boxplot(meta_data_frame['nr_files'], vert=False, flierprops=dict(markerfacecolor='r', marker='s'))
plt.xlabel("nr_files")
plt.yticks([])
plt.show()

# %% [markdown]
# Now we can collect or define the other parameters for the models.

# %%
# take the shortest video as input shape, so all videos can fit
INPUT_SHAPE = min(meta_data_frame['nr_files'])

# load the label_map
LABEL_MAP_PATH = 'data/label_map.txt'
kinetics_classes = [x.strip() for x in open(LABEL_MAP_PATH, 'r')]

# extract the number of classes from the label_map
NUM_CLASSES = len(kinetics_classes)

# now define the frame dimesions 
FRAME_HEIGHT = 224
FRAME_WIDTH = 224

# and the number of channels 
NUM_RGB_CHANNELS = 3
NUM_FLOW_CHANNELS = 2

# %% [markdown]
# ## Load the models
# Now that we have the input parameters ready, we can (down)-load the pre-trained models.
# - 1 model for processing the RGB images
# - 1 model for processing the optical flow
#
# NOTE: the optical flow model has 1 frame less than the RGB model. This is because the optical flow is calculated between 2 consecutive frames, and thus at the first frame there is no previous frame.

# %%
# get the I3D rgb model
rgb_model = Inception_Inflated3d(
    include_top=True,
    weights='rgb_imagenet_and_kinetics',
    input_shape=(INPUT_SHAPE, FRAME_HEIGHT, FRAME_WIDTH, NUM_RGB_CHANNELS),
    classes=NUM_CLASSES
)

# get the I3D flow model
flow_model = Inception_Inflated3d(
    include_top=True,
    weights='flow_imagenet_and_kinetics',
    input_shape=(INPUT_SHAPE - 1, FRAME_HEIGHT, FRAME_WIDTH, NUM_FLOW_CHANNELS),
    classes=NUM_CLASSES
)
# Out:
# /home/willem/Projects/i3d_keras/src/i3d_inception.py:98: UserWarning: This model usually expects 1 or 3 input channels. However, it was passed an input_shape with 2 input channels.
#   warnings.warn(

# %% [markdown]
# ## Make predictions
#
# Now that the models are ready, we can predict the acitivity in the videos.

# %%
# we collect the outcome in this list for later processing
results = []

# loop over all class_names and video's
for class_name in os.listdir(test_dir):
    for video_name in os.listdir(os.path.join(test_dir, class_name)):

        # get the first x files from the directory 
        files = sorted(os.listdir(os.path.join(test_dir, class_name, video_name)))[:INPUT_SHAPE]
        
        # map the files to file paths
        file_paths = [os.path.join(test_dir, class_name, video_name, file) for file in files]
        
        # collect the rgb files
        npy_rgb_output = f"data/interim/{class_name}_{video_name}_rgb.npy"
        if not os.path.exists(npy_rgb_output):
            rgb = run_rgb(file_paths)
            np.save(npy_rgb_output, rgb)
        rgb_sample = np.load(npy_rgb_output)
        
        # collect the optical flow files
        npy_flow_output = f"data/interim/{class_name}_{video_name}_flow.npy"
        if not os.path.exists(npy_flow_output):
            flow = run_flow(file_paths)
            np.save(npy_flow_output, flow)
        flow_sample = np.load(npy_flow_output)
        
        # make prediction
        rgb_logits = rgb_model.predict(rgb_sample)
        flow_logits = flow_model.predict(flow_sample)
        
        # produce final model logits
        sample_logits = rgb_logits + flow_logits
        
        # produce softmax output from model logit for class probabilities
        sample_logits = sample_logits[0] # we are dealing with just one example
        sample_predictions = np.exp(sample_logits) / np.sum(np.exp(sample_logits))
        
        # sort the indices
        sorted_indices = np.argsort(sample_predictions)[::-1]
        
        # print some data
        print(f"{video_name} = {class_name} => prediction {kinetics_classes[sorted_indices[0]]} ({sample_predictions[sorted_indices[0]] * 100:.2f}%)")
        
        # collect the data
        results.append({
            'video_name':video_name,
            'class_name':class_name,
            'y_pred':kinetics_classes[sorted_indices[0]],
            'confidence':sample_predictions[sorted_indices[0]]
        })

# collect the results in a dataframe
results_df = pd.DataFrame(results)
results_df.to_csv('data/processed/results_experiment_1.csv')
results_df.head()
# Out:
# g24_c01 = Diving => prediction springboard diving (95.36%)
# g23_c04 = Diving => prediction springboard diving (99.99%)
# g23_c02 = Diving => prediction springboard diving (99.90%)
# g22_c04 = Diving => prediction springboard diving (80.49%)
# g21_c04 = Diving => prediction springboard diving (63.38%)
# g23_c05 = Diving => prediction springboard diving (99.71%)
# g22_c06 = Diving => prediction springboard diving (97.90%)
# g21_c06 = Diving => prediction springboard diving (92.59%)
# g22_c02 = Diving => prediction springboard diving (81.61%)
# g24_c06 = Diving => prediction springboard diving (90.56%)
# g24_c04 = Diving => prediction dunking basketball (99.91%)
# g21_c02 = Diving => prediction springboard diving (99.94%)
# g25_c01 = Diving => prediction springboard diving (91.79%)
# g22_c01 = Diving => prediction springboard diving (100.00%)
# g24_c03 = Diving => prediction springboard diving (81.79%)
# g21_c01 = Diving => prediction springboard diving (99.76%)
# g21_c07 = Diving => prediction springboard diving (86.95%)
# g25_c04 = Diving => prediction springboard diving (92.36%)
# g23_c03 = Diving => prediction somersaulting (96.76%)
# g21_c05 = Diving => prediction faceplanting (76.47%)
# g24_c07 = Diving => prediction springboard diving (98.98%)
# g23_c01 = Diving => prediction somersaulting (63.67%)
# g21_c03 = Diving => prediction springboard diving (98.91%)
# g22_c03 = Diving => prediction springboard diving (99.39%)
# g25_c02 = Diving => prediction springboard diving (83.93%)
# g25_c03 = Diving => prediction springboard diving (98.60%)
# g24_c02 = Diving => prediction springboard diving (96.59%)
# g24_c05 = Diving => prediction springboard diving (82.07%)
# g23_c06 = Diving => prediction springboard diving (88.08%)
# g22_c05 = Diving => prediction springboard diving (97.31%)
# g24_c01 = HulaHoop => prediction hula hooping (100.00%)
# g23_c04 = HulaHoop => prediction hula hooping (100.00%)
# g23_c02 = HulaHoop => prediction hula hooping (100.00%)
# g22_c04 = HulaHoop => prediction hula hooping (100.00%)
# g21_c04 = HulaHoop => prediction hula hooping (100.00%)
# g23_c05 = HulaHoop => prediction hula hooping (100.00%)
# g22_c02 = HulaHoop => prediction hula hooping (100.00%)
# g24_c04 = HulaHoop => prediction hula hooping (100.00%)
# g21_c02 = HulaHoop => prediction hula hooping (100.00%)
# g25_c01 = HulaHoop => prediction hula hooping (100.00%)
# g22_c01 = HulaHoop => prediction hula hooping (100.00%)
# g24_c03 = HulaHoop => prediction hula hooping (100.00%)
# g21_c01 = HulaHoop => prediction hula hooping (100.00%)
# g25_c04 = HulaHoop => prediction hula hooping (100.00%)
# g23_c03 = HulaHoop => prediction hula hooping (100.00%)
# g23_c01 = HulaHoop => prediction hula hooping (100.00%)
# g25_c05 = HulaHoop => prediction hula hooping (100.00%)
# g21_c03 = HulaHoop => prediction hula hooping (100.00%)
# g22_c03 = HulaHoop => prediction hula hooping (100.00%)
# g25_c02 = HulaHoop => prediction hula hooping (100.00%)
# g25_c03 = HulaHoop => prediction hula hooping (100.00%)
# g24_c02 = HulaHoop => prediction hula hooping (100.00%)
# g23_c06 = HulaHoop => prediction hula hooping (100.00%)
# g22_c05 = HulaHoop => prediction hula hooping (100.00%)
# g24_c01 = PlayingPiano => prediction playing piano (93.48%)
# g23_c04 = PlayingPiano => prediction playing organ (77.60%)
# g23_c02 = PlayingPiano => prediction playing piano (99.80%)
# g22_c04 = PlayingPiano => prediction playing piano (99.99%)
# g21_c04 = PlayingPiano => prediction playing piano (93.80%)
# g22_c02 = PlayingPiano => prediction playing piano (98.85%)
# g24_c04 = PlayingPiano => prediction playing piano (99.86%)
# g21_c02 = PlayingPiano => prediction playing chess (33.64%)
# g25_c01 = PlayingPiano => prediction playing organ (69.88%)
# g22_c01 = PlayingPiano => prediction playing piano (99.12%)
# g24_c03 = PlayingPiano => prediction playing piano (97.56%)
# g21_c01 = PlayingPiano => prediction playing organ (59.92%)
# g25_c04 = PlayingPiano => prediction playing piano (59.28%)
# g23_c03 = PlayingPiano => prediction playing piano (99.96%)
# g23_c01 = PlayingPiano => prediction playing piano (100.00%)
# g21_c03 = PlayingPiano => prediction playing piano (58.31%)
# g22_c03 = PlayingPiano => prediction playing piano (100.00%)
# g25_c02 = PlayingPiano => prediction playing piano (54.58%)
# g25_c03 = PlayingPiano => prediction playing organ (58.41%)
# g24_c02 = PlayingPiano => prediction playing piano (99.05%)
# g24_c01 = Biking => prediction riding a bike (92.30%)
# g23_c04 = Biking => prediction riding a bike (92.67%)
# g23_c02 = Biking => prediction riding a bike (99.23%)
# g22_c04 = Biking => prediction riding mountain bike (64.76%)
# g21_c04 = Biking => prediction riding a bike (90.67%)
# g21_c12 = Biking => prediction riding a bike (87.92%)
# g21_c08 = Biking => prediction riding a bike (88.77%)
# g21_c06 = Biking => prediction riding mountain bike (99.64%)
# g22_c02 = Biking => prediction riding a bike (72.24%)
# g24_c08 = Biking => prediction riding a bike (71.95%)
# g24_c06 = Biking => prediction riding unicycle (97.76%)
# g24_c04 = Biking => prediction riding a bike (99.81%)
# g21_c02 = Biking => prediction riding a bike (56.04%)
# g25_c01 = Biking => prediction riding a bike (99.91%)
# g22_c01 = Biking => prediction riding a bike (100.00%)
# g24_c03 = Biking => prediction biking through snow (72.27%)
# g21_c01 = Biking => prediction riding a bike (83.49%)
# g21_c07 = Biking => prediction riding a bike (87.85%)
# g21_c09 = Biking => prediction riding mountain bike (95.42%)
# g25_c04 = Biking => prediction riding unicycle (100.00%)
# g23_c03 = Biking => prediction riding a bike (99.70%)
# g21_c05 = Biking => prediction riding mountain bike (59.82%)
# g24_c07 = Biking => prediction biking through snow (71.98%)
# g21_c10 = Biking => prediction riding mountain bike (65.85%)
# g21_c11 = Biking => prediction riding mountain bike (78.41%)
# g23_c01 = Biking => prediction riding a bike (100.00%)
# g21_c03 = Biking => prediction riding a bike (88.68%)
# g22_c03 = Biking => prediction riding a bike (47.60%)
# g25_c02 = Biking => prediction riding a bike (72.52%)
# g25_c03 = Biking => prediction riding a bike (98.30%)
# g24_c02 = Biking => prediction riding a bike (94.45%)
# g24_c05 = Biking => prediction riding a bike (59.06%)
# g22_c05 = Biking => prediction riding a bike (74.75%)
# g24_c01 = SalsaSpin => prediction salsa dancing (100.00%)
# g23_c04 = SalsaSpin => prediction salsa dancing (100.00%)
# g23_c02 = SalsaSpin => prediction salsa dancing (99.98%)
# g22_c04 = SalsaSpin => prediction salsa dancing (86.22%)
# g21_c04 = SalsaSpin => prediction salsa dancing (99.98%)
# g22_c02 = SalsaSpin => prediction salsa dancing (97.62%)
# g24_c04 = SalsaSpin => prediction salsa dancing (99.98%)
# g21_c02 = SalsaSpin => prediction salsa dancing (99.97%)
# g25_c01 = SalsaSpin => prediction salsa dancing (100.00%)
# g22_c01 = SalsaSpin => prediction salsa dancing (99.89%)
# g24_c03 = SalsaSpin => prediction salsa dancing (100.00%)
# g21_c01 = SalsaSpin => prediction salsa dancing (100.00%)
# g25_c04 = SalsaSpin => prediction salsa dancing (99.89%)
# g23_c03 = SalsaSpin => prediction salsa dancing (100.00%)
# g21_c05 = SalsaSpin => prediction salsa dancing (99.99%)
# g23_c01 = SalsaSpin => prediction salsa dancing (100.00%)
# g21_c03 = SalsaSpin => prediction salsa dancing (99.98%)
# g22_c03 = SalsaSpin => prediction salsa dancing (97.44%)
# g25_c02 = SalsaSpin => prediction salsa dancing (69.79%)
# g25_c03 = SalsaSpin => prediction salsa dancing (99.99%)
# g24_c02 = SalsaSpin => prediction salsa dancing (100.00%)
# g24_c05 = SalsaSpin => prediction salsa dancing (100.00%)
# g22_c05 = SalsaSpin => prediction salsa dancing (99.66%)
#   video_name class_name              y_pred  confidence
# 0    g24_c01     Diving  springboard diving    0.953604
# 1    g23_c04     Diving  springboard diving    0.999876
# 2    g23_c02     Diving  springboard diving    0.998995
# 3    g22_c04     Diving  springboard diving    0.804863
# 4    g21_c04     Diving  springboard diving    0.633752

# %% [markdown]
# ## Analyse the results

# %% [markdown]
# Before we dive in the qualtiy of the predictions, first let's get an idea how confident the model is about it's predictions.

# %%
confidences = {}

# collect all confidences per y_pred
for y_pred, group in results_df.groupby('y_pred'):
    confidences[y_pred] = group['confidence']

# now plot the confidence distribution per y_pred
fig, ax = plt.subplots(figsize=(30, 8))
plt.title('Prediction confidences')
plt.xlabel("predicted class names")
plt.ylabel("confidence")
ax.violinplot(confidences.values())
ax.set_xticks(np.arange(1, len(confidences) + 1))
ax.set_xticklabels(confidences.keys())
plt.show()

# %% [markdown]
# Ideally we would like to see high confidences, so that we know the model is certain about it's predictions. But there is some spreading towards 50% condifence, so there is something going on.
#
# Now let's calculate how well the model predicts?

# %%
def map_values(row):
    if row['class_name'] == 'Diving':
        return 'springboard diving'
    if row['class_name'] == 'SalsaSpin':
        return 'salsa dancing'
    if row['class_name'] == 'HulaHoop':
        return 'hula hooping'
    if row['class_name'] == 'Biking':
        return 'riding a bike'
    if row['class_name'] == 'PlayingPiano':
        return 'playing piano'
    return np.nan

# map the custom map names to the likely kinetic class names so we can measure the accuracy
results_df['y_true'] = results_df.apply(lambda row : map_values(row), axis=1) 

# Collect the y values
y_true = results_df['y_true']
y_pred = results_df['y_pred']

# fetching the class_names (from y_true and y_pred an map them to the original kinetic class position)
labels = [kinetics_class for kinetics_class in kinetics_classes if kinetics_class in set(y_true).union(set(y_pred))]

# define the figure
fig, axs = plt.subplots(1, 2, figsize=(30, 8))

# plot 2 confusion matrixes
for title, normalize, column in [("Confusion matrix, without normalization", None, 0), ("Normalized confusion matrix", 'true', 1)]:

    # calculate the confusion matrix
    cm = sklearn.metrics.confusion_matrix(y_true, y_pred, sample_weight=None, labels=None, normalize=normalize)

    # build the confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels).plot(ax=axs[column], cmap=plt.cm.Blues, xticks_rotation='vertical')
    disp.ax_.set_title(title)

# %% [markdown]
# Okay, the model made no mistakes at `hula hooping` and `salsa dancing`. At the other videos mistakes were made.
#
# Now let's an overall idication how wel the model did on our test set.

# %%
print(sklearn.metrics.classification_report(y_true, y_pred))
# Out:
#                       precision    recall  f1-score   support
#
#  biking through snow       0.00      0.00      0.00         0
#   dunking basketball       0.00      0.00      0.00         0
#         faceplanting       0.00      0.00      0.00         0
#         hula hooping       1.00      1.00      1.00        24
#        playing chess       0.00      0.00      0.00         0
#        playing organ       0.00      0.00      0.00         0
#        playing piano       1.00      0.75      0.86        20
#        riding a bike       1.00      0.70      0.82        33
# riding mountain bike       0.00      0.00      0.00         0
#      riding unicycle       0.00      0.00      0.00         0
#        salsa dancing       1.00      1.00      1.00        23
#        somersaulting       0.00      0.00      0.00         0
#   springboard diving       1.00      0.87      0.93        30
#
#             accuracy                           0.85       130
#            macro avg       0.38      0.33      0.35       130
#         weighted avg       1.00      0.85      0.92       130
# /home/willem/.virtualenvs/i3d_keras/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/willem/.virtualenvs/i3d_keras/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/willem/.virtualenvs/i3d_keras/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Discussion
# ### Video cropping
# As mentioned before, i've deliberatlty cropped the first part of the video so that i can predict all videos. i've could have chosen different strategies like:
# - chose n discrete bins on video lengths and build models for each bin. If there is a short video than this doesn't have to be a bottleneck for all videos
# - crop videos around the center
# - crop the video in multiple segments, predict each segment and combine the outcomes of all segments to 1 prediction
# - a combination of the above.
# I assume that the more video data is analysed, the higher the accuracy would be. I noticed that a diving video was poorly predicted so i've looked into it. The video was quite similar to another, but the activity was started later in the video, and thus it makes sense that the model couldn't recognize the acitivty, because it was cropped before it started.
#
# ### Custom class naming
# I've also mapped the 5 "custom" classes to the "most likely" kinetic class names. But in the case of `Biking` there are 5 different variants of `riding a bike` in the kinetic dataset, so in some cases (videos) it makes sense that the confidence is low, and possibly incorrect. For example `Biking` video `g25_c04`; it's a small boy riding a bike, recorded from the back. There is only 1 wheel visible throughout the video so it makes sense that this video is classified as `riding unicycle`.
#
# This is my first itteration with the model and the dataset. So now i have a baseline, my next step would be to apply `error analysis` and figure out which next step would be most benificial.

# %% [markdown]
# # Training

# %% [markdown]
# The original kinetics 400 [dataset](https://deepmind.com/research/open-source/kinetics) contains of approximate `219367` video segments from youtube, devided over `400` categories. If they were devided evenly this would mean approximatly `549` videos per category. In the training directory there are approximatly `140` videos per catergory. So training from scratch would't adchieve the same performance. So i would apply transfer learning.
#
# ### Transfer learning
# DISCLAIMER: i've experience in transfer learning different networks (with tensorflow), but no experience in I3D networks. So before i start i would read [this paper](https://ieeexplore.ieee.org/document/9191289).
#
# For transfer learning, I would take the following steps:
# - My first steps would to create a balanced dataset, with both RGB images and optical flow images.
# - Next i would download the I3D RGB and Flow models without the top layers.
# - Now that i have the base models, i would freeze all the layers (so their weights and biasses wouldn't be altered during training)
# - Next i would create a new model (one for RGB and one for FLOW), and add the following layers
#  - preprocessing layer (for rescaling and normalizing the input)
#  - the frozen base model
#  - average pooling layer (reduce the number of parameters and make the features more robust)
#  - dropout layer (for more regularization)
#  - softmax activation layer (for the classification)
# - Once the models are build an compiled, we're ready to train the model
#
# After the model is trained, i would thoroughly evaluate the model on an hold-out set. If the model performs reasonably well i would fine tune the model futher, by taking the following steps.
# - i would unfreeze a certain section of the frozen layers of the base model. There are different strategies, but my first pick would be the last (top) 30% layers.
# - Next i would compile the model again and resume training with an lower learning rate
#
# Now the new models are again thoroughly evaluated, so i could define an accuracy.
